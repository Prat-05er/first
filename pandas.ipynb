# %% [markdown]
# ### Pandas

# %%
import pandas as pd #### we use pandas for datasets like csv, excel, json

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/Datasets/main/hotel_bookings.csv")

# %%
df.head(10) ### to get first 10 records, default value is 5
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.tail(10) #### to get last 10 values
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119380             August                        35
# 119381             August                        35
# 119382             August                        35
# 119383             August                        35
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.dtypes ## display different datatypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# company, country, children and agent columns have empty values

# %%
df.isnull()
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.describe(include='all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# ### Pandas series and dataframes

# %% [markdown]
# Series
#
# 1. Form of sequencially one- dimensional arrays
#
# 2. All elements one data type
#
# 3. Can be created from lists, tuples and arrays

# %% [markdown]
# #### DataFrame
#
# two dimensional data structure that can store various types of data

# %%
import pandas as pd
import numpy as np

# %%
g1=pd.Series(["M","F","M","M","F"]) #### series using list
g1
# Out:
# 0    M
# 1    F
# 2    M
# 3    M
# 4    F
# dtype: object

# %%
g2=pd.Series(np.array(["M","F","M","M","F"])) #### series using numpy array
g2
# Out:
# 0    M
# 1    F
# 2    M
# 3    M
# 4    F
# dtype: object

# %%
type(g2)
# Out:
# pandas.core.series.Series

# %%
type(g1)
# Out:
# pandas.core.series.Series

# %%
#### series using dictionary
dic={"a":1,"b":2,3:"c",4:15}
s=pd.Series(dic)

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index
# Out:
# Index(['a', 'b', 3, 4], dtype='object')

# %%
s.values
# Out:
# array([1, 2, 'c', 15], dtype=object)

# %%
g2.values
# Out:
# array(['M', 'F', 'M', 'M', 'F'], dtype=object)

# %%
g2.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# ### DataFrame in Pandas

# %%
### example of creating a dataframe using a dictionary
d1=pd.DataFrame({"Name":["Aman","Shubham","Lokesh"],"Age":[25,31,28],"Salary":[18000,20000,19000]})
d1
# Out:
#       Name  Age  Salary
# 0     Aman   25   18000
# 1  Shubham   31   20000
# 2   Lokesh   28   19000

# %%
d1["Salary"]
# Out:
# 0    18000
# 1    20000
# 2    19000
# Name: Salary, dtype: int64

# %%
type(d1["Salary"])
# Out:
# pandas.core.series.Series

# %%
d1["Salary"][0]
# Out:
# 18000

# %%
s1=pd.Series([0,1,2],index=["cricket","tennis","polo"])

# %%
s2=pd.Series([12,13,14],index=["cricket","basketball","polo"])

# %%
s1+s2
# Out:
# basketball     NaN
# cricket       12.0
# polo          16.0
# tennis         NaN
# dtype: float64

# %% [markdown]
# ### Note

# %% [markdown]
# positional argument is followed by keyword argument whenever a function is called
#
# Incorrect way :
#
# s2=pd.Series(index=["cricket","basketball","polo"],[12,13,14])
#
# Correct way :
#
# s2=pd.Series([12,13,14],index=["cricket","basketball","polo"])

# %% [markdown]
# #### Arithmetic operations in series

# %% [markdown]
# Syntax -> seriesname.f()
#
# where f() can be sum(),min(),max(),mean(),std(),var(),median()
#
# also sort_values() is a method used to sort the values in increasing order of index in the series

# %%
#### example of sorted values in series
s1.sort_values()
# Out:
# cricket    0
# tennis     1
# polo       2
# dtype: int64

# %% [markdown]
# #### we can also use lambda function to perform arithmetic operations on series

# %%
s=pd.Series([1,2,3],name="rollno")
s
# Out:
# 0    1
# 1    2
# 2    3
# Name: rollno, dtype: int64

# %%
s.apply(lambda x:x**2)
# Out:
# 0    1
# 1    4
# 2    9
# Name: rollno, dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
d2=pd.DataFrame([["a",23,True],["b",21,False]], columns=["Letter","Number","Boolean"])

# %%
d2
# Out:
#   Letter  Number  Boolean
# 0      a      23     True
# 1      b      21    False

# %%
d2.index=['first','second']

# %%
d2
# Out:
#        Letter  Number  Boolean
# first       a      23     True
# second      b      21    False

# %%
d2.rename(index={'first':'1st'})
# Out:
#        Letter  Number  Boolean
# 1st         a      23     True
# second      b      21    False

# %% [markdown]
# #### but this will again revert back to original index when called again.

# %%
d2
# Out:
#        Letter  Number  Boolean
# first       a      23     True
# second      b      21    False

# %% [markdown]
# #### to avoid this, we need to set inplace= True

# %%
d2.rename(index={'first':'1st'}, inplace=True)

# %%
d2
# Out:
#        Letter  Number  Boolean
# 1st         a      23     True
# second      b      21    False

# %%
d2
# Out:
#        Letter  Number  Boolean
# 1st         a      23     True
# second      b      21    False

# %% [markdown]
# #### similar concept for column change

# %%
d2.rename(columns={'Number':'Numbers'},inplace=True)

# %%
d2
# Out:
#        Letter  Numbers  Boolean
# 1st         a       23     True
# second      b       21    False

# %%
df=d2[:]

# %%
df.drop('second')
# Out:
#     Letter  Numbers  Boolean
# 1st      a       23     True

# %%
df
# Out:
#        Letter  Numbers  Boolean
# 1st         a       23     True
# second      b       21    False

# %% [markdown]
# again we need to set inplace as True to prevent the dataframe from reverting back

# %%
df.drop('second',inplace=True)
# Out:
# C:\Users\favor\AppData\Local\Temp\ipykernel_6016\3716026372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('second',inplace=True)

# %%
df
# Out:
#     Letter  Numbers  Boolean
# 1st      a       23     True

# %% [markdown]
# #### To drop a column, we need to write additional syntax axis=1

# %%
df.drop('Boolean', axis=1, inplace=True)
# Out:
# C:\Users\favor\AppData\Local\Temp\ipykernel_6016\1383743694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('Boolean', axis=1, inplace=True)

# %%
df
# Out:
#     Letter  Numbers
# 1st      a       23

# %%
d1=pd.DataFrame({"Name":["Aman","Shubham","Lokesh"],"Age":[25,31,28],"Salary":[18000,20000,19000]})
d1
# Out:
#       Name  Age  Salary
# 0     Aman   25   18000
# 1  Shubham   31   20000
# 2   Lokesh   28   19000

# %%
#### dropping multiple rows in the DataFrame 
###d1.drop('Aman',axis=0)
d1.drop(['Age','Salary'],inplace=True,axis=1)

# %%
d1
# Out:
#       Name
# 0     Aman
# 1  Shubham
# 2   Lokesh

# %% [markdown]
# ##### locating values for a particlar index in the DataFrame

# %%
d1=pd.DataFrame({"Name":["Aman","Shubham","Lokesh"],"Age":[25,31,28],"Salary":[18000,20000,19000]})
d1
# Out:
#       Name  Age  Salary
# 0     Aman   25   18000
# 1  Shubham   31   20000
# 2   Lokesh   28   19000

# %%
d1.loc[2]
# Out:
# Name      Lokesh
# Age           28
# Salary     19000
# Name: 2, dtype: object

# %%
##### multiple values 
d1.loc[[1,2]]
# Out:
#       Name  Age  Salary
# 1  Shubham   31   20000
# 2   Lokesh   28   19000

# %%
d1.set_index("Name",inplace=True)

# %%
d1
# Out:
#          Age  Salary
# Name
# Aman      25   18000
# Shubham   31   20000
# Lokesh    28   19000

# %%
d1.iloc[0,1:] #### [ 0 (row), 1 : (1st column onwards)
# Out:
# Salary    18000
# Name: Aman, dtype: int64

# %%
### adding a common value column to all of rows
d1['Gender']='Male'

# %%
d1
# Out:
#          Age  Salary Gender
# Name
# Aman      25   18000   Male
# Shubham   31   20000   Male
# Lokesh    28   19000   Male

# %%
d1
# Out:
#          Age  Salary Gender  Parag
# Name
# Aman      25   18000   Male     26
# Shubham   31   20000   Male  21000
# Lokesh    28   19000   Male   Male
# 3          0       0      0      0

# %%
d1.drop('Parag',inplace=True,axis=1)

# %%
d1
# Out:
#          Age  Salary Gender
# Name
# Aman      25   18000   Male
# Shubham   31   20000   Male
# Lokesh    28   19000   Male
# 3          0       0      0

# %%
d1.loc["Parag"]=[26,21000,"Male"]

# %%
d1
# Out:
#          Age  Salary Gender
# Name
# Aman      25   18000   Male
# Shubham   31   20000   Male
# Lokesh    28   19000   Male
# 3          0       0      0
# Parag     26   21000   Male

# %%
d1.drop(3,inplace=True)

# %%
# Out:
#          Age  Salary Gender
# Name
# Aman      25   18000   Male
# Shubham   31   20000   Male
# Lokesh    28   19000   Male
# Parag     26   21000   Male
